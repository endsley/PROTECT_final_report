# %%
#!/usr/bin/env python

# %%
import os
import sys
if os.path.exists('/home/chieh/code/wuML'):
	sys.path.insert(0,'/home/chieh/code/wuML')
import wuml
from proj_tools import *

# %%
wuml.set_terminal_print_options(precision=3)
all_files = wuml.list_all_files_in_directory('./pk_files', with_extension='.pk')
all_files.sort()

# %%
summary_table = np.empty((0, 10))
for f in all_files:
	net = wuml.load_torch_network('./pk_files/' + f, load_as_cpu_or_gpu='cpu')
	if 'D5' in f: 
		data_names = 'D5'
	elif 'D4' in f: 
		data_names = 'D4_subset_of_D3'
	elif 'D3' in f: 
		data_names = 'D3_Imputed_Balanced_regression'
#
	data = wuml.wData(xpath='../data/' + data_names + '.csv', batch_size=32, 
						label_type='continuous', label_column_name='gestationAge',
						mv_columns_to_extra_data='preterm_best', preprocess_data='center and scale',
						first_row_is_label=True)
#
	[labels, prob_of_positive, gestages] = net(data, output_type='ndarray')
	result_summary = [f] + display_results(data.Y, gestages, data.xDat[0], labels, prob_of_positive, display=False)		# ['Accᶜ', 'Precisionᶜ', 'Recallᶜ', 'AUCᶜ', 'Accᴿ', 'Precisionᴿ', 'Recallᴿ', 'Avg L1 error', 'Avg Lᨖ error']
	summary_table = np.vstack((summary_table, result_summary))
# Out:
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 5000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=32, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=40, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=40, out_features=40, bias=True) , relu
# 		Linear(in_features=40, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=32, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=40, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 5000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=32, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=40, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=40, out_features=40, bias=True) , relu
# 		Linear(in_features=40, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=32, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=40, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 5000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=32, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=40, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=40, out_features=40, bias=True) , relu
# 		Linear(in_features=40, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=32, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=40, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 3000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=32, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=40, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=40, out_features=40, bias=True) , relu
# 		Linear(in_features=40, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=32, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=40, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 3000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=32, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=40, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=40, out_features=40, bias=True) , relu
# 		Linear(in_features=40, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=32, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=40, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 3000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=25, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=20, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=20, out_features=20, bias=True) , relu
# 		Linear(in_features=20, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=25, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=20, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=20, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=1, bias=True) , none
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 3000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=25, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=20, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=20, out_features=20, bias=True) , relu
# 		Linear(in_features=20, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=25, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=20, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=20, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 5000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=25, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=30, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=30, out_features=30, bias=True) , relu
# 		Linear(in_features=30, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=25, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=30, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 3000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=25, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=20, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=20, out_features=20, bias=True) , relu
# 		Linear(in_features=20, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=25, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=20, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 4000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=14, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=10, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=10, out_features=10, bias=True) , relu
# 		Linear(in_features=10, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=14, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=10, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=10, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 4000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=14, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=10, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=10, out_features=10, bias=True) , relu
# 		Linear(in_features=10, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=14, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=10, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=10, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 4000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=14, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=10, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=10, out_features=10, bias=True) , relu
# 		Linear(in_features=10, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		Linear(in_features=1000, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=14, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=10, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1000, bias=True) , relu
# 		BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=1000, out_features=1, bias=True) , none
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 4000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=14, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=10, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=10, out_features=10, bias=True) , relu
# 		Linear(in_features=10, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		Linear(in_features=2000, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=14, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=10, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=2000, bias=True) , relu
# 		BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=2000, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 3000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=14, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=10, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=10, out_features=10, bias=True) , relu
# 		Linear(in_features=10, out_features=500, bias=True) , relu
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		Linear(in_features=500, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=14, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=10, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 3000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=14, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=10, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=10, out_features=10, bias=True) , relu
# 		Linear(in_features=10, out_features=500, bias=True) , relu
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		Linear(in_features=500, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=14, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=10, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=500, bias=True) , relu
# 		BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=500, out_features=1, bias=True) , none
#
# All Networks
# 	Batch size: 32:
# 	Learning rate: 0.001
# 	Max number of epochs: 3000
# 	Cost Function: costFunction
# 	Device type: 'cpu'
# 	Networks 0 Structure
# 		Linear(in_features=14, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=10, bias=True) , none
# 	Networks 1 Structure
# 		Linear(in_features=10, out_features=10, bias=True) , relu
# 		Linear(in_features=10, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		Linear(in_features=800, out_features=200, bias=True) , relu
# 		Linear(in_features=200, out_features=14, bias=True) , none
# 	Networks 2 Structure
# 		Linear(in_features=10, out_features=2, bias=True) , none
# 	Networks 3 Structure
# 		Linear(in_features=2, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=800, bias=True) , relu
# 		BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 		Linear(in_features=800, out_features=1, bias=True) , none

# %%
cnames = ['file', 'Accᶜ', 'Precisionᶜ', 'Recallᶜ', 'AUCᶜ', 'Accᴿ', 'Precisionᴿ', 'Recallᴿ', 'Avg L1 error', 'Avg Lᨖ error']
summary_table = wuml.ensure_DataFrame(summary_table, columns=cnames)
wuml.jupyter_print(summary_table, display_all_rows=True, display_all_columns=True)
# Out:
#                            file   Accᶜ Precisionᶜ Recallᶜ   AUCᶜ   Accᴿ Precisionᴿ Recallᴿ Avg L1 error Avg Lᨖ error
# 0              D3_CE_1000_90.pk  0.994      0.992   0.997    1.0  0.995      0.994   0.997        0.391         5.79
# 1              D3_CE_1000_99.pk  0.998      0.995     1.0  0.999  0.995      0.993   0.997        0.566          8.0
# 2              D3_CE_2000_99.pk  0.998      0.995     1.0  0.999  0.996      0.996   0.997        0.337         6.28
# 3              D3_CE_800_0.6.pk  0.959      0.956   0.961  0.974  0.952      0.974   0.928        0.872         17.9
# 4              D3_CE_800_0.8.pk  0.991      0.986   0.997  0.999  0.992      0.991   0.992        0.396         5.84
# 5        D4_BNeck_800_0.8_20.pk  0.998      0.997     1.0    1.0  0.988      0.993   0.983        0.383          4.8
# 6          D4_BNeck_800_1_20.pk    1.0      0.999     1.0    1.0  0.993      0.999   0.987        0.362         4.21
# 7              D4_CE_2000_99.pk  0.997      0.994     1.0    1.0  0.996      0.995   0.997        0.372         4.31
# 8             D4_CE_800_1_20.pk  0.999      0.998     1.0    1.0  0.992      0.997   0.987        0.364         4.75
# 9         D5_BNeck_1000_1_10.pk  0.996      0.992     1.0    1.0  0.995      0.994   0.997        0.332         4.33
# 10      D5_BNeck_2000_0.9_10.pk  0.992      0.989   0.994  0.999  0.983      0.987    0.98        0.539        17.43
# 11           D5_CE_1000_1_10.pk  0.974      0.998    0.95    1.0  0.966      0.993    0.94        0.791          3.8
# 12           D5_CE_2000_1_10.pk  0.998      0.997     1.0    1.0  0.963      0.999   0.927         0.63         3.59
# 13            D5_CE_500_1_10.pk  0.995      0.993   0.997    1.0   0.99       0.99    0.99        0.434         3.56
# 14  D5_CE_500_1_10_explained.pk  0.995      0.993   0.997    1.0   0.99       0.99    0.99        0.434         3.56
# 15          D5_CE_800_0.9_10.pk  0.985       0.98   0.991  0.997   0.98      0.985   0.976         0.58         5.03
