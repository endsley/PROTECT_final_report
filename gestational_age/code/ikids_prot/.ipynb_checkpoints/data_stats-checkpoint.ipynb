# %%
#!/usr/bin/env python

# %%
import os
import sys
if os.path.exists('/home/chieh/code/wPlotLib'):
	sys.path.insert(0,'/home/chieh/code/wPlotLib')
if os.path.exists('/home/chieh/code/wuML'):
	sys.path.insert(0,'/home/chieh/code/wuML')

# %%
from proj_tools import *
import wuml
import numpy as np
import torch
import torch.nn as nn

# %%
data = wuml.wData(xpath='./data/D10.csv', batch_size=32, first_row_is_label=True)
data.get_feature_histograms('gestationAge', num_bins=10, ylogScale=False)
gAges = np.round(data.get_columns('gestationAge', return_type='ndarray'))
premat = np.round(data.get_columns('preterm_best', return_type='ndarray'))

# %%
wuml.get_label_stats(gAges, print_stat=True)
wuml.get_label_stats(premat, print_stat=True)
# Out:
#     class id  num sample  percentage
# 0       23.0         2.0    0.001070
# 1       24.0         1.0    0.000535
# 2       25.0         1.0    0.000535
# 3       26.0         2.0    0.001070
# 4       27.0         1.0    0.000535
# 5       28.0         1.0    0.000535
# 6       29.0         1.0    0.000535
# 7       30.0         2.0    0.001070
# 8       31.0         5.0    0.002674
# 9       32.0         7.0    0.003743
# 10      33.0        14.0    0.007487
# 11      34.0        22.0    0.011765
# 12      35.0        16.0    0.008556
# 13      36.0        46.0    0.024599
# 14      37.0       119.0    0.063636
# 15      38.0       274.0    0.146524
# 16      39.0       563.0    0.301070
# 17      40.0       502.0    0.268449
# 18      41.0       245.0    0.131016
# 19      42.0        40.0    0.021390
# 20      43.0         6.0    0.003209
#    class id  num sample  percentage
# 0       0.0      1717.0    0.918182
# 1       1.0       153.0    0.081818
#    class id  num sample  percentage
# 0       0.0      1717.0    0.918182
# 1       1.0       153.0    0.081818
