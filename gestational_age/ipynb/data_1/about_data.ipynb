# %%
#!/usr/bin/env python
import os
import sys
#import wuml
if os.path.exists('/home/chieh/code/wuML'):
	sys.path.insert(0,'/home/chieh/code/wuML')
    
import wuml
import numpy as np
import wplotlib

data = wuml.wData('../data/chem.exposures.csv', row_id_with_label=0, label_column_name='finalga_best', label_type='continuous')
mdp = wuml.missing_data_stats(data)
wuml.jupyter_print(data.shape)
wuml.jupyter_print(data.df.columns)
# Out:
# 2022-03-24 11:43:16.203943: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# <html><body><h3>(1177, 96)</h3></body></html>
# ...

# %%
cn = data.df.columns.to_numpy()
missiness = wuml.ensure_wData(np.vstack((cn,mdp)))
wuml.jupyter_print(missiness, display_all_columns=True)
# Out:
#            0    1         2         3         4         5         6   \
# 0  Unnamed: 0   id       MBP      MBzP      MCNP      MCOP      MCPP
# 1         0.0  0.0  0.034834  0.034834  0.034834  0.034834  0.034834
#
#          7         8         9         10        11        12        13  \
# 0     MECPP    MECPTP     MEHHP    MEHHTP      MEHP     MEOHP       MEP
# 1  0.034834  0.545455  0.034834  0.545455  0.034834  0.034834  0.034834
#
#          14        15        16        17        18        19        20  \
# 0      MHBP     MHiBP      MiBP      MONP     DCP24     DCP25       BPB
# 1  0.268479  0.268479  0.034834  0.545455  0.102804  0.102804  0.102804
#
#          21        22        23        24        25        26        27  \
# 0       BP3       BPA       BPF       BPS       EPB       MPB       PPB
# 1  0.102804  0.102804  0.335599  0.290569  0.290569  0.102804  0.102804
#
#          28        29        30        31        32          33        34  \
# ...
