# %%
#!/usr/bin/env python

# %%
import os
import sys
#import wuml
if os.path.exists('/home/chieh/code/wuML'):
	sys.path.insert(0,'/home/chieh/code/wuML')
    
import wuml
import numpy as np
import wplotlib

# %%
#data = wuml.wData('../data/Chem_decimated_imputed.csv', label_column_name='finalga_best', 
#					label_type='continuous', row_id_with_label=0)
data = wuml.wData('../../data/data.comp3.csv', row_id_with_label=0)

# %%
Dep = wuml.feature_wise_correlation(data, get_top_corr_pairs=True)
wuml.jupyter_print(Dep)
# Out:
#                             0
# MEHHP      MEOHP     0.991351
# DCP24      DCP25     0.978683
# MEHHP      MEHP      0.958598
# MEHP       MEOHP     0.956220
# MECPP      MEOHP     0.939693
#            MEHHP     0.928018
# MCOP       MCPP      0.896984
# MECPP      MEHP      0.842408
# OH_PHE_2_3 OH_FLU_2  0.838705
# Unnamed: 0 id        0.814636

# %%
Dep2 = wuml.feature_wise_HSIC(data, get_top_dependent_pairs=True)
wuml.jupyter_print(Dep2)
# Out:
#                               0
# MEHHP      MEOHP       0.864862
# Unnamed: 0 id          0.833372
# MECPP      MEOHP       0.686461
#            MEHHP       0.649277
# MEHP       MEOHP       0.429775
# MEHHP      MEHP        0.416056
# OH_PHE_2_3 OH_FLU_2    0.395579
# MPB        PPB         0.370978
# OH_PHE_1   OH_PHE_2_3  0.362363
# MECPP      MEHP        0.339294
