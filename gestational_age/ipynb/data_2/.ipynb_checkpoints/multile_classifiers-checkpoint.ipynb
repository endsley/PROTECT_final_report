# %%
#!/usr/bin/env python

# %%
import wuml
# Out:
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# 0.1.36ubuntu1 is an invalid version and will not be supported in a future release

# %%
data = wuml.wData(xpath='../../data/data.comp3.csv', batch_size=20, 
					label_type='continuous', label_column_name='finalga_best', 
					row_id_with_label=0, columns_to_ignore=['id'])

# %%
print('\n\nRun all regressors sorted by Accuracy')
results = wuml.run_every_classifier(data, y=data.Y, order_by='Test')
Y = results['GP'](data)
print(Y)
# Out:
# Run all regressors sorted by Accuracy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 print('\n\nRun all regressors sorted by Accuracy')
# ----> 2 results = wuml.run_every_classifier(data, y=data.Y, order_by='Test')
#       3 Y = results['GP'](data)
#       4 print(Y)
#
# File ~/.local/lib/python3.8/site-packages/wuml/classification.py:132, in run_every_classifier(data, y, y_column_name, order_by, q)
#     130 df = pd.DataFrame()
#     131 for reg in regressors:
# --> 132 	results[reg] = classification(data, y=y, classifier=reg, split_train_test=True, q=q)
#     133 	df = df.append(results[reg].result_summary(print_out=False))
#     135 if order_by == 'Test': results['Train/Test Summary'] = df.sort_values(['Test','Train'], ascending=False)
#
# File ~/.local/lib/python3.8/site-packages/wuml/classification.py:70, in classification.__init__(self, data, y, y_column_name, split_train_test, classifier, kernel, networkStructure, max_epoch, learning_rate, q)
#      67 	model = wuml.IKDR(data, q=q, y=y)
#      68 else: raise ValueError('Unrecognized Classifier')
# ---> 70 model.fit(NP(X_train), S(NP(y_train)))
#      71 self.ŷ_train = model.predict(NP(X_train))
#      72 self.Train_acc = wuml.accuracy(S(NP(y_train)), self.ŷ_train)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/gaussian_process/_gpc.py:715, in GaussianProcessClassifier.fit(self, X, y)
#     712     else:
#     713         raise ValueError("Unknown multi-class mode %s" % self.multi_class)
# --> 715 self.base_estimator_.fit(X, y)
#     717 if self.n_classes_ > 2:
#     718     self.log_marginal_likelihood_value_ = np.mean(
#     719         [
#     720             estimator.log_marginal_likelihood()
#     721             for estimator in self.base_estimator_.estimators_
#     722         ]
#     723     )
#
# File ~/.local/lib/python3.8/site-packages/sklearn/multiclass.py:330, in OneVsRestClassifier.fit(self, X, y)
#     325 # A sparse LabelBinarizer, with sparse_output=True, has been shown to
#     326 # outperform or match a dense label binarizer in all cases and has also
#     327 # resulted in less or equal memory consumption in the fit_ovr function
#     328 # overall.
#     329 self.label_binarizer_ = LabelBinarizer(sparse_output=True)
# --> 330 Y = self.label_binarizer_.fit_transform(y)
#     331 Y = Y.tocsc()
#     332 self.classes_ = self.label_binarizer_.classes_
#
# File ~/.local/lib/python3.8/site-packages/sklearn/preprocessing/_label.py:324, in LabelBinarizer.fit_transform(self, y)
#     304 def fit_transform(self, y):
#     305     """Fit label binarizer/transform multi-class labels to binary labels.
#     306
#     307     The output of transform is sometimes referred to as
#    (...)
#     322         will be of CSR format.
#     323     """
# --> 324     return self.fit(y).transform(y)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/preprocessing/_label.py:301, in LabelBinarizer.fit(self, y)
#     298     raise ValueError("y has 0 samples: %r" % y)
#     300 self.sparse_input_ = sp.issparse(y)
# --> 301 self.classes_ = unique_labels(y)
#     302 return self
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/multiclass.py:101, in unique_labels(*ys)
#      99 _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     100 if not _unique_labels:
# --> 101     raise ValueError("Unknown label type: %s" % repr(ys))
#     103 ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
