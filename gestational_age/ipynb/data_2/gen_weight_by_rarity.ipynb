# %%
#!/usr/bin/env python
import os
import sys
if os.path.exists('/home/chieh/code/wuML'):
	sys.path.insert(0,'/home/chieh/code/wuML')
if os.path.exists('/home/chieh/code/wPlotLib'):
	sys.path.insert(0,'/home/chieh/code/wPlotLib')
    
import wuml 
import numpy as np
import scipy.stats
from wplotlib import histograms
from wplotlib import lines

# %%
data = wuml.wData('../../data/data.comp3.csv', label_column_name='finalga_best', 
					label_type='continuous', row_id_with_label=0)

Ty = data.get_column_names_as_a_list()
wuml.jupyter_print(Ty, display_all_rows=True)
# Out:
#              0
# 0   Unnamed: 0
# 1           id
# 2          MBP
# 3         MBzP
# 4         MCNP
# 5         MCOP
# 6         MCPP
# 7        MECPP
# 8        MEHHP
# 9         MEHP
# 10       MEOHP
# 11         MEP
# 12        MiBP
# 13       DCP24
# 14       DCP25
# 15         BP3
# 16         BPA
# 17         MPB
# 18         PPB
# 19         TCS
# 20    As.urine
# 21    Ba.urine
# 22    Co.urine
# 23    Cs.urine
# 24    Cu.urine
# 25    Hg.urine
# 26    Mn.urine
# 27    Mo.urine
# 28    Ni.urine
# 29    Sn.urine
# 30    Zn.urine
# 31    OH_NAP_1
# 32    OH_PHE_1
# 33    OH_PYR_1
# 34  OH_PHE_2_3
# 35    OH_FLU_2
# 36    OH_NAP_2
# 37    OH_PHE_4
# 38    OH_PHE_9
# 39      preBMI
# 40       ppsex
# 41       ISAGE
# 42     edu_cat

# %%
H1 = histograms(data.Y, num_bins=20, title='Gestational Age Histogram', facecolor='blue', α=0.5, path=None)
H1.show()

# %%
H2 = histograms(data.Y, num_bins=20, title='Gestational Age Histogram', facecolor='blue', α=0.5, path=None, ylogScale=True )
H2.show()

# %%
sample_weights = wuml.get_likelihood_weight(data.Y)
H3 = histograms(sample_weights.X, num_bins=20, title='Sample Weight Histogram', facecolor='blue', α=0.5, path=None, ylogScale=True )

# %%
wuml.output_two_columns_side_by_side(data.Y, sample_weights.X, labels=['Y','W'], rounding=3)
# Out:
#           Y        W
# 0    37.429    3.040
# 1    39.571    1.020
# 2    35.000   22.366
# 3    39.143    1.011
# 4    38.857    1.082
# 5    38.429    1.337
# 6    38.714    1.145
# 7    38.571    1.229
# 8    39.143    1.011
# 9    39.714    1.048
# 10   39.714    1.048
# 11   37.714    2.339
# 12   38.571    1.229
# 13   39.429    1.003
# 14   39.143    1.011
# 15   36.000    9.699
# 16   38.857    1.082
# 17   38.286    1.470
# 18   38.714    1.145
# 19   34.143   25.084
# 20   39.286    1.000
# 21   35.571   13.367
# 22   41.571    4.506
# 23   39.000    1.038
# 24   35.571   13.367
# 25   39.429    1.003
# 26   39.571    1.020
# 27   39.857    1.089
# 28   42.429   20.810
# 29   24.429  111.120
# 30   40.714    1.721
# 31   38.714    1.145
# 32   39.571    1.020
# 33   39.286    1.000
# 34   37.429    3.040
# 35   40.429    1.407
# 36   33.857   24.088
# 37   38.143    1.633
# 38   39.286    1.000
# 39   41.571    4.506
# 40   39.429    1.003
# 41   35.714   11.909
# ...

# %%
type(sample_weights)
sample_weights.to_csv('../../data/comp3_weights.csv', include_column_names=False)
